# %% [markdown]
# # conditional statements in python
# 1. python have 4 types of conditional statements
# 2. `if` statement
# 3. `elif` statement
# 4. `else` statement
# 5. `nested` statement
#
# ```python syntax - if
# if (condition): # if condition is True then execute or run statements inside if block
#     statement1
#     statement2...
# ```
# ```python - if, else
# if(condition):
#     statement1
#     statement2...
# else:
#     statement1
#     statement2...
# ```
# ```python -if,elif,else
# if(condition):
#     statements1..n
# elif(condition2):
#     statements1..n
# elif(condition3):
#     statement1..n
#
# else:
#     statements1..n
# ```

# %%
#write a program to find the given number is odd?
number = int(input("please enter the number"))
if (number%2 == 1):
    print(number,"is odd number")
# Out:
# please enter the number 1001
# 1001 is odd number

# %%
#write a program to find the given number is even or odd?
num=int(input("please enter the number"))
if(num%2==0):gbgbgbv
    print(num,"is even number")
else:
    print(num,"is odd number")
# Out:
# please enter the number 28
# 28 is even number

# %%
#write a program to find the given number is positive or negative or zero?
n = int(input("please enter the number"))
if(n>0):
    print(n,"is a positive number")
elif (n<0):
    print(n,"is a negative number")
else:
    print(n,"is a zero")
# Out:
# please enter the number -12
# -12 is a negative number

# %%
"""
write a program to find the grades based on marks
1. if marks in between 80-100 - grade is A 
2. if marks in between 60-79 - grade is B 
3. if marks in between 40-59 - grade is C 
4. if marks in between 25-39 - grade is D 
5. if marks in between 0-24 - grade is Fail
6. if marks other than above input is - please enter correct marks
"""
marks=int(input("please enter student marks here:"))
if (marks>=80 and marks<=100):
    print(marks,"grade is A")
elif(marks>=60 and marks<=79):
    print(marks,"grade is B")
elif(marks>=40 and marks<=59):
    print(marks,"grade is C")
elif(marks>=25 and marks<=39):
    print(marks,"grade is D")
elif(marks>=0 and marks<=24):
    print(marks,"grade is fail")
else:
    print("please enter correct marks")
# Out:
# please enter student marks here: 100
# 100 grade is A

# %%
#write a program to find the largest number from three numbers?
number1 = int(input("enter the first number here:"))
number2 = int(input("enter the second number here:"))
number3 = int(input("enter the third number here:"))
if (number1>number2 and number2):
    print(number1,"is the largest number")
elif(number2>number3 and number1):
    print(number2,"is the largest number")
else:
    print(number3,"is the largest number")
# Out:
# enter the first number here: 99
# enter the second number here: 500
# enter the third number here: 392
# 500 is the largest number

# %%
#write a program to validate login credentials using conditional statements?
username=str(input("please enter username here:"))
if(username=="tia@123"):
    print("username is valid")
    password=str(input("please enter user password here:"))
    if (password=="TIA@12345"):
        print("user details are successfully validated, Thank you")
    else:
        print("password is wrong")
else:
    print("username is invalid")
# Out:
# please enter username here: tia@123
# username is valid
# please enter user password here: TIA@12345
# user details are successfully validated, Thank you

# %%
"""
write a program to find the even number with number of digits
1. if number in between 1 to 9 then output is - 1 is digit even number 
2. if number in between 10 to 99 then output is - 2 is digit even number
3. if number in between 100 to 999 then output is - 3 is digit even number 
4. if number in between 1000 to 9999 then output is - 4 is digit even number 
5. if other than above range then output is -weired even number
"""
n = int(input("please enter the number here:"))
if(n%2 == 0):
    if(n>=1 and n<=9):
       print(n,"is an 1 digit even number")
    elif(n>=10 and n<=99):
       print(n,"is an 2 digit even number")
    elif(n>=100 and n<=999):
       print(n,"is an 3 digit even number")
    elif(n>=1000 and n<=9999):
       print(n,"is an 4 digit even number")
    else:
       print("weird even number")
else:
    print(n,"is not even number")
# Out:
# please enter the number here: 8888
# 8888 is an 4 digit even number
