# %% [markdown]
# #Variables in Python
# 1. variable is memory allocation to a value
# 2. examples are `name="varshitha" ` 'age=15`

# %%
name="varshitha"
age=15
salary=1000000
print(name)
print(age)
print (salary)
# Out:
# varshitha
# 15
# 1000000

# %% [markdown]
# # key points to define variables
# 1. variables does not start with digit
# 2. variables does not allowed special characters
# 3. do not use keyboard as a variables
# 4.

# %%
1name="varshitha"
print(name)
